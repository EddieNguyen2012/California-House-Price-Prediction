# %% [markdown]
# Load and combine the datasets, then restrict the dataset to residential single-family home sales to define the modeling population.

# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
import numpy as np

files = sorted(glob.glob("CRMLSSold*.csv"))
print(files)

df = pd.concat((pd.read_csv(f) for f in files), ignore_index=True)
df = df[(df["PropertyType"] == "Residential") &
        (df["PropertySubType"] == "SingleFamilyResidence")].copy()
df.shape
df["ClosePrice"]
# Out:
# ['CRMLSSold202507.csv', 'CRMLSSold202508.csv', 'CRMLSSold202509.csv', 'CRMLSSold202510.csv', 'CRMLSSold202511.csv', 'CRMLSSold202512.csv']
# 3          1040000.0
# 4          2400000.0
# 8          1908500.0
# 9          1050000.0
# 10         5900000.0
#              ...
# 131876      640000.0
# 131878    12000000.0
# 131892      600000.0
# 131893      380000.0
# 131918      842000.0
# Name: ClosePrice, Length: 67247, dtype: float64

# %%
df.columns
# Out:
# Index(['BuyerAgentAOR', 'ListAgentAOR', 'Flooring', 'ViewYN', 'WaterfrontYN',
#        'BasementYN', 'PoolPrivateYN', 'OriginalListPrice', 'ListingKey',
#        'ListAgentEmail', 'CloseDate', 'ClosePrice', 'ListAgentFirstName',
#        'ListAgentLastName', 'Latitude', 'Longitude', 'UnparsedAddress',
#        'PropertyType', 'LivingArea', 'ListPrice', 'DaysOnMarket',
#        'ListOfficeName', 'BuyerOfficeName', 'CoListOfficeName',
#        'ListAgentFullName', 'CoListAgentFirstName', 'CoListAgentLastName',
#        'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName',
#        'FireplacesTotal', 'AssociationFeeFrequency', 'AboveGradeFinishedArea',
#        'ListingKeyNumeric', 'MLSAreaMajor', 'TaxAnnualAmount',
#        'CountyOrParish', 'MlsStatus', 'ElementarySchool', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'StreetNumberNumeric',
#        'ListingId', 'BathroomsTotalInteger', 'City', 'TaxYear',
#        'BuildingAreaTotal', 'BedroomsTotal', 'ContractStatusChangeDate',
#        'ElementarySchoolDistrict', 'CoBuyerAgentFirstName',
#        'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea',
#        'BusinessType', 'StateOrProvince', 'CoveredSpaces',
#        'MiddleOrJuniorSchool', 'FireplaceYN', 'Stories', 'HighSchool',
#        'Levels', 'LotSizeDimensions', 'LotSizeArea', 'MainLevelBedrooms',
#        'NewConstructionYN', 'GarageSpaces', 'HighSchoolDistrict', 'PostalCode',
#        'AssociationFee', 'LotSizeSquareFeet', 'MiddleOrJuniorSchoolDistrict'],
#       dtype='object')

# %% [markdown]
# I first visually inspected a few rows to ensure the data was loaded correctly and variables look reasonable. I also examined variable types and missingness patterns to assess data usability before feature selection.

# %%
df.head()
df.info()
df["ClosePrice"].describe()
df.isna().mean().sort_values(ascending=False).head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67247 entries, 3 to 131918
# Data columns (total 78 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   BuyerAgentAOR                 67236 non-null  object
#  1   ListAgentAOR                  67236 non-null  object
#  2   Flooring                      43478 non-null  object
#  3   ViewYN                        61001 non-null  object
#  4   WaterfrontYN                  27 non-null     object
#  5   BasementYN                    1605 non-null   object
#  6   PoolPrivateYN                 62164 non-null  object
#  7   OriginalListPrice             67116 non-null  float64
#  8   ListingKey                    67247 non-null  int64
#  9   ListAgentEmail                67014 non-null  object
#  10  CloseDate                     67247 non-null  object
#  11  ClosePrice                    67247 non-null  float64
#  12  ListAgentFirstName            66776 non-null  object
#  13  ListAgentLastName             67240 non-null  object
#  14  Latitude                      67242 non-null  float64
#  15  Longitude                     67242 non-null  float64
#  16  UnparsedAddress               67199 non-null  object
#  17  PropertyType                  67247 non-null  object
#  18  LivingArea                    67214 non-null  float64
#  19  ListPrice                     67247 non-null  float64
#  20  DaysOnMarket                  67247 non-null  int64
#  21  ListOfficeName                67247 non-null  object
#  22  BuyerOfficeName               66513 non-null  object
#  23  CoListOfficeName              17843 non-null  object
#  24  ListAgentFullName             67224 non-null  object
#  25  CoListAgentFirstName          15731 non-null  object
#  26  CoListAgentLastName           15776 non-null  object
#  27  BuyerAgentMlsId               67164 non-null  object
#  28  BuyerAgentFirstName           66968 non-null  object
#  29  BuyerAgentLastName            67211 non-null  object
#  30  FireplacesTotal               0 non-null      float64
#  31  AssociationFeeFrequency       16719 non-null  object
#  32  AboveGradeFinishedArea        0 non-null      float64
#  33  ListingKeyNumeric             67247 non-null  int64
#  34  MLSAreaMajor                  57280 non-null  object
#  35  TaxAnnualAmount               0 non-null      float64
#  36  CountyOrParish                67247 non-null  object
#  37  MlsStatus                     67247 non-null  object
#  38  ElementarySchool              8697 non-null   object
#  39  AttachedGarageYN              59036 non-null  object
#  40  ParkingTotal                  67247 non-null  float64
#  41  BuilderName                   2992 non-null   object
#  42  PropertySubType               67247 non-null  object
#  43  LotSizeAcres                  66133 non-null  float64
#  44  SubdivisionName               23605 non-null  object
#  45  BuyerOfficeAOR                62609 non-null  object
#  46  YearBuilt                     67211 non-null  float64
#  47  StreetNumberNumeric           67181 non-null  float64
#  48  ListingId                     67247 non-null  object
#  49  BathroomsTotalInteger         67240 non-null  float64
#  50  City                          67231 non-null  object
#  51  TaxYear                       0 non-null      float64
#  52  BuildingAreaTotal             4517 non-null   float64
#  53  BedroomsTotal                 67247 non-null  float64
#  54  ContractStatusChangeDate      67247 non-null  object
#  55  ElementarySchoolDistrict      0 non-null      float64
#  56  CoBuyerAgentFirstName         6176 non-null   object
#  57  PurchaseContractDate          67242 non-null  object
#  58  ListingContractDate           67247 non-null  object
#  59  BelowGradeFinishedArea        488 non-null    float64
#  60  BusinessType                  0 non-null      object
#  61  StateOrProvince               67247 non-null  object
#  62  CoveredSpaces                 0 non-null      float64
#  63  MiddleOrJuniorSchool          8800 non-null   object
#  64  FireplaceYN                   67198 non-null  object
#  65  Stories                       60538 non-null  float64
#  66  HighSchool                    11461 non-null  object
#  67  Levels                        62802 non-null  object
#  68  LotSizeDimensions             4331 non-null   object
#  69  LotSizeArea                   66139 non-null  float64
#  70  MainLevelBedrooms             41302 non-null  float64
#  71  NewConstructionYN             62135 non-null  object
#  72  GarageSpaces                  64536 non-null  float64
#  73  HighSchoolDistrict            49288 non-null  object
#  74  PostalCode                    67246 non-null  object
#  75  AssociationFee                47724 non-null  float64
#  76  LotSizeSquareFeet             66132 non-null  float64
#  77  MiddleOrJuniorSchoolDistrict  0 non-null      float64
# dtypes: float64(27), int64(3), object(48)
# memory usage: 40.5+ MB
# MiddleOrJuniorSchoolDistrict    1.000000
# FireplacesTotal                 1.000000
# AboveGradeFinishedArea          1.000000
# TaxAnnualAmount                 1.000000
# TaxYear                         1.000000
# ElementarySchoolDistrict        1.000000
# CoveredSpaces                   1.000000
# BusinessType                    1.000000
# WaterfrontYN                    0.999598
# BelowGradeFinishedArea          0.992743
# BasementYN                      0.976133
# BuilderName                     0.955507
# LotSizeDimensions               0.935596
# BuildingAreaTotal               0.932830
# CoBuyerAgentFirstName           0.908159
# dtype: float64

# %% [markdown]
# I dropped columns with 50% or more missing values.

# %%
missing_rate = df.isna().mean()

drop_cols = missing_rate[missing_rate >= 0.5].index
print(list(drop_cols))

df = df.drop(columns=drop_cols)
# Out:
# ['WaterfrontYN', 'BasementYN', 'CoListOfficeName', 'CoListAgentFirstName', 'CoListAgentLastName', 'FireplacesTotal', 'AssociationFeeFrequency', 'AboveGradeFinishedArea', 'TaxAnnualAmount', 'ElementarySchool', 'BuilderName', 'SubdivisionName', 'TaxYear', 'BuildingAreaTotal', 'ElementarySchoolDistrict', 'CoBuyerAgentFirstName', 'BelowGradeFinishedArea', 'BusinessType', 'CoveredSpaces', 'MiddleOrJuniorSchool', 'HighSchool', 'LotSizeDimensions', 'MiddleOrJuniorSchoolDistrict']

# %% [markdown]
# Drop unrelated columns:
# "ListPrice", "OriginalListPrice", "ListingContractDate", "ListAgentAOR", "ListAgentEmail", "ListAgentFirstName", "ListAgentLasName", "ListAgentFullName", "ListingKey", "ListingKeyNumeric", "ListingId".

# %%
df = df.drop(columns=["ListPrice", "OriginalListPrice", "ListingContractDate", "ListAgentAOR", "ListAgentEmail", "ListAgentFirstName",
                      "ListAgentLastName", "ListAgentFullName", "ListingKey", "ListingKeyNumeric", "ListingId"])
df
# Out:
#              BuyerAgentAOR                    Flooring ViewYN PoolPrivateYN  \
# 3                 SanDiego                         NaN  False         False
# 4              PalmSprings                 Carpet,Tile   True          True
# 8              Mlslistings  Carpet,Laminate,Stone,Tile   True           NaN
# 9         PacificSouthwest                         NaN   True         False
# 10             Mlslistings                         NaN  False           NaN
# ...                    ...                         ...    ...           ...
# 131876            Glendale                   Tile,Wood   True         False
# 131878         Mlslistings            Carpet,Tile,Wood   True           NaN
# 131892  NorthSanLuisObispo             Carpet,Laminate   True         False
# 131893    TheInlandGateway                         NaN   True         False
# 131918    TheInlandGateway                    Laminate   True         False
#
#          CloseDate  ClosePrice   Latitude   Longitude  \
# 3       2025-07-31   1040000.0  33.157973 -117.253250
# 4       2025-07-31   2400000.0  33.803727 -116.534532
# 8       2025-07-23   1908500.0  36.603859 -121.868261
# 9       2025-07-29   1050000.0  33.151355 -117.101143
# 10      2025-07-31   5900000.0  37.390272 -122.110274
# ...            ...         ...        ...         ...
# 131876  2025-12-05    640000.0  34.608952 -118.259648
# 131878  2025-12-04  12000000.0  37.443497 -122.150296
# 131892  2025-12-17    600000.0  35.903719 -120.982965
# 131893  2025-12-15    380000.0  34.261375 -117.211842
# 131918  2025-12-01    842000.0  33.746161 -118.022037
#
#                  UnparsedAddress PropertyType  ...  Stories  Levels  \
# 3              1937 Elm Ridge Dr  Residential  ...      2.0     Two
# 4           1094 E Deepwell Road  Residential  ...      1.0     One
# 8             124 Seafoam Avenue  Residential  ...      NaN     NaN
# 9              1947 Greenview Rd  Residential  ...      1.0     One
# 10              484 Panchita Way  Residential  ...      NaN     NaN
# ...                          ...          ...  ...      ...     ...
# 131876  7211 Elizabeth Lake Road  Residential  ...      1.0     One
# 131878       535 Kingsley Avenue  Residential  ...      NaN     NaN
# 131892     70255 New Pleyto Road  Residential  ...      1.0     One
# 131893     27121 Peninsula Drive  Residential  ...      1.0     One
# 131918          14862 Sabre Lane  Residential  ...      1.0     One
#
#        LotSizeArea MainLevelBedrooms NewConstructionYN GarageSpaces  \
# 3           5318.0               NaN             False          2.0
# 4          12632.0               NaN             False          2.0
# 8           3600.0               NaN             False          2.0
# 9          17248.0               NaN               NaN          2.0
# 10         10200.0               NaN             False          1.0
# ...            ...               ...               ...          ...
# 131876    105281.0               3.0             False          3.0
# 131878     15118.0               NaN             False          2.0
# 131892        20.0               3.0             False          0.0
# 131893      9620.0               3.0             False          1.0
# 131918      7275.0               3.0             False          2.0
#
#                  HighSchoolDistrict PostalCode AssociationFee  \
# 3                               NaN      92081          173.0
# 4                               NaN      92264            NaN
# 8                             Other      93940            NaN
# 9                   Escondido Union      92026            0.0
# 10                            Other      94022            NaN
# ...                             ...        ...            ...
# 131876        Antelope Valley Union      93551            0.0
# 131878            Palo Alto Unified      94301            NaN
# 131892        King City Joint Union      93426            0.0
# 131893             Rim of the World      92352            0.0
# 131918  Huntington Beach Union High      92647            0.0
#
#        LotSizeSquareFeet
# 3                 5318.0
# 4                12632.0
# 8                 3600.0
# 9                17248.0
# 10               10200.0
# ...                  ...
# 131876          105281.0
# 131878           15118.0
# 131892          871200.0
# 131893            9620.0
# 131918            7275.0
#
# [67247 rows x 44 columns]

# %%
missing_cols = df.columns[df.isna().any()]
numeric_cols = df.select_dtypes(include='number').columns
numeric_missing_cols = missing_cols.intersection(numeric_cols)
numeric_missing_cols
# Out:
# Index(['Latitude', 'Longitude', 'LivingArea', 'LotSizeAcres', 'YearBuilt',
#        'StreetNumberNumeric', 'BathroomsTotalInteger', 'Stories',
#        'LotSizeArea', 'MainLevelBedrooms', 'GarageSpaces', 'AssociationFee',
#        'LotSizeSquareFeet'],
#       dtype='object')

# %%
df_missing = df.isna().sum()[df.isna().sum() > 0]
print(df_missing)
# Out:
# BuyerAgentAOR               11
# Flooring                 23769
# ViewYN                    6246
# PoolPrivateYN             5083
# Latitude                     5
# Longitude                    5
# UnparsedAddress             48
# LivingArea                  33
# BuyerOfficeName            734
# BuyerAgentMlsId             83
# BuyerAgentFirstName        279
# BuyerAgentLastName          36
# MLSAreaMajor              9967
# AttachedGarageYN          8211
# LotSizeAcres              1114
# BuyerOfficeAOR            4638
# YearBuilt                   36
# StreetNumberNumeric         66
# BathroomsTotalInteger        7
# City                        16
# PurchaseContractDate         5
# FireplaceYN                 49
# Stories                   6709
# Levels                    4445
# LotSizeArea               1108
# MainLevelBedrooms        25945
# NewConstructionYN         5112
# GarageSpaces              2711
# HighSchoolDistrict       17959
# PostalCode                   1
# AssociationFee           19523
# LotSizeSquareFeet         1115
# dtype: int64

# %%
cols = [
    "LivingArea",
    "LotSizeAcres",
    "LotSizeArea",
    "LotSizeSquareFeet",
    "BathroomsTotalInteger",
    "Stories",
    "GarageSpaces",
    "Latitude",
    "Longitude"
]

df[cols].median()
# Out:
# LivingArea               1810.000000
# LotSizeAcres                0.167000
# LotSizeArea              7095.000000
# LotSizeSquareFeet        7275.000000
# BathroomsTotalInteger       2.000000
# Stories                     1.000000
# GarageSpaces                2.000000
# Latitude                   34.086853
# Longitude                -118.036806
# dtype: float64

# %%
for col in cols:
    df[col] = df[col].fillna(df[col].median())

df[cols].isna().sum()
# Out:
# LivingArea               0
# LotSizeAcres             0
# LotSizeArea              0
# LotSizeSquareFeet        0
# BathroomsTotalInteger    0
# Stories                  0
# GarageSpaces             0
# Latitude                 0
# Longitude                0
# dtype: int64

# %%
df["CloseDate"] = pd.to_datetime(df["CloseDate"], errors="coerce")
df["close_month"] = df["CloseDate"].dt.to_period("M")

df[["CloseDate", "close_month"]]
# Out:
#         CloseDate close_month
# 3      2025-07-31     2025-07
# 4      2025-07-31     2025-07
# 8      2025-07-23     2025-07
# 9      2025-07-29     2025-07
# 10     2025-07-31     2025-07
# ...           ...         ...
# 131876 2025-12-05     2025-12
# 131878 2025-12-04     2025-12
# 131892 2025-12-17     2025-12
# 131893 2025-12-15     2025-12
# 131918 2025-12-01     2025-12
#
# [67247 rows x 2 columns]

# %% [markdown]
#  Remove top and bottom 0.5% of ClosePrice within the given dataframe.
#  Training set:

# %%
last_month = df["close_month"].max()
df["close_month"].value_counts().sort_index().tail(6)
test_df = df[df["close_month"] == last_month].copy()
train_df = df[df["close_month"] < last_month].copy()

def trim_closeprice(df, price_col="ClosePrice", lower_q=0.005, upper_q=0.995):

    low = df[price_col].quantile(lower_q)
    high = df[price_col].quantile(upper_q)
    
    df_trimmed = df[
        (df[price_col] >= low) &
        (df[price_col] <= high)
    ].copy()
    
    return df_trimmed, low, high

train_trim, train_low, train_high = trim_closeprice(train_df)

print("Lower:", train_low)
print("Upper:", train_high)
print("Before:", train_df.shape)
print("After:", train_trim.shape)
# Out:
# Lower: 189000.0
# Upper: 8801525.094999941
# Before: (56792, 45)
# After: (56226, 45)

# %% [markdown]
# Testing set:

# %%
test_trim, test_low, test_high = trim_closeprice(test_df)

print("Lower:", test_low)
print("Upper:", test_high)
print("Before:", test_df.shape)
print("After:", test_trim.shape)
# Out:
# Lower: 179000.0
# Upper: 8586499.999999978
# Before: (10455, 45)
# After: (10350, 45)

# %% [markdown]
# Verify proportion of observations removed after outlier trimming.

# %%
print("Train removed:", 1 - len(train_trim) / len(train_df))
print("Test removed:", 1 - len(test_trim) / len(test_df))
# Out:
# Train removed: 0.00996619242146779
# Test removed: 0.010043041606886627

# %% [markdown]
# Check the ClosePrice numeric integrity prior to transformation

# %%
train_df["ClosePrice"].dtype, train_df["ClosePrice"].head()
cp_train = pd.to_numeric(train_df["ClosePrice"], errors="coerce")
print("missing after numeric:", cp_train.isna().mean())
print("min:", cp_train.min(), "num <= 0:", (cp_train <= 0).sum())
# Out:
# missing after numeric: 0.0
# min: 0.0 num <= 0: 1

# %%
test_df["ClosePrice"].dtype, test_df["ClosePrice"].head()
cp_test = pd.to_numeric(test_df["ClosePrice"], errors="coerce")
print("missing after numeric:", cp_test.isna().mean())
print("min:", cp_test.min(), "num <= 0:", (cp_test <= 0).sum())
# Out:
# missing after numeric: 0.0
# min: 31000.0 num <= 0: 0

# %%
cp_train = train_df["ClosePrice"]
cp_train = cp_train[cp_train > 0]

# %% [markdown]
# The histograms below compare the log-transformed ClosePrice distribution before and after trimming extreme values. Trimming the top and bottom 0.5% reduces tail heaviness and results in a more symmetric distribution.

# %%
cp_before_train = train_df["ClosePrice"]
cp_before_train = cp_before_train[cp_before_train > 0]

cp_after_train = train_trim["ClosePrice"]
cp_after_train = cp_after_train[cp_after_train > 0]

fig, axes = plt.subplots(1, 2, figsize=(12,4))

axes[0].hist(np.log(cp_before_train), bins=50)
axes[0].set_title("Before Trimming")
axes[0].set_xlabel("log(ClosePrice)")

axes[1].hist(np.log(cp_after_train), bins=50)
axes[1].set_title("After Trimming (0.5% each tail)")
axes[1].set_xlabel("log(ClosePrice)")

plt.tight_layout()
plt.show()

# %%
cp_before_test = test_df["ClosePrice"]

cp_after_test = test_trim["ClosePrice"]

fig, axes = plt.subplots(1, 2, figsize=(12,4))

axes[0].hist(np.log(cp_before_test), bins=50)
axes[0].set_title("Before Trimming")
axes[0].set_xlabel("log(ClosePrice)")

axes[1].hist(np.log(cp_after_test), bins=50)
axes[1].set_title("After Trimming (0.5% each tail)")
axes[1].set_xlabel("log(ClosePrice)")

plt.tight_layout()
plt.show()

# %%
train_trim['logPrice'] = np.log(train_df['ClosePrice'])
test_trim['logPrice'] = np.log(test_df['ClosePrice'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# Some possible predictors:
# 1. LivingArea, BedroomsTotal, BathroomsTotalInteger, Stories, Levels, MainLevelBedrooms, GarageSpaces, ParkingTotal...
# 2. Latitude, Longitude, City, CountyOrParish, StateOrProvince...
# 3. YearBuilt, NewConstructionYN, FireplaceYN, ViewYN, PoolPrivateYN, AssociationFee...

# %%
train_trim = train_trim.drop(columns="close_month")
test_trim = test_trim.drop(columns="close_month")

# %%
train_trim.to_csv("train_trim.csv", index=False)
test_trim.to_csv("test_trim.csv", index=False)

# %%
train = pd.read_csv("train_trim.csv")
train
# Out:
#           BuyerAgentAOR                    Flooring ViewYN PoolPrivateYN  \
# 0              SanDiego                         NaN  False         False
# 1           PalmSprings                 Carpet,Tile   True          True
# 2           Mlslistings  Carpet,Laminate,Stone,Tile   True           NaN
# 3      PacificSouthwest                         NaN   True         False
# 4           Mlslistings                         NaN  False           NaN
# ...                 ...                         ...    ...           ...
# 56221  CoastalMendocino               Laminate,Tile   True         False
# 56222       PacificWest                         NaN  False         False
# 56223      CitrusValley                         NaN   True         False
# 56224        HighDesert                         NaN   True         False
# 56225  TheInlandGateway                        Wood  False         False
#
#         CloseDate  ClosePrice   Latitude   Longitude       UnparsedAddress  \
# 0      2025-07-31   1040000.0  33.157973 -117.253250     1937 Elm Ridge Dr
# 1      2025-07-31   2400000.0  33.803727 -116.534532  1094 E Deepwell Road
# 2      2025-07-23   1908500.0  36.603859 -121.868261    124 Seafoam Avenue
# 3      2025-07-29   1050000.0  33.151355 -117.101143     1947 Greenview Rd
# 4      2025-07-31   5900000.0  37.390272 -122.110274      484 Panchita Way
# ...           ...         ...        ...         ...                   ...
# 56221  2025-11-26    675000.0  39.450744 -123.760617   30380 Jacobson Lane
# 56222  2025-11-15    805000.0  34.080766 -118.203070     3527 Flora Avenue
# 56223  2025-11-21    700000.0  32.703615 -117.073444     112 S 58th Street
# 56224  2025-11-05    215000.0  34.501814 -117.775047     19805 Pearblossom
# 56225  2025-11-17   1175000.0  33.964531 -117.694962   15906 Kingston Road
#
#       PropertyType  ...  Levels  LotSizeArea MainLevelBedrooms  \
# 0      Residential  ...     Two      5318.00               NaN
# 1      Residential  ...     One     12632.00               NaN
# 2      Residential  ...     NaN      3600.00               NaN
# 3      Residential  ...     One     17248.00               NaN
# 4      Residential  ...     NaN     10200.00               NaN
# ...            ...  ...     ...          ...               ...
# 56221  Residential  ...     Two         1.83               NaN
# 56222  Residential  ...     One      7219.00               3.0
# 56223  Residential  ...     One      6900.00               6.0
# 56224  Residential  ...     One    218781.00               3.0
# 56225  Residential  ...     Two      4937.00               1.0
#
#       NewConstructionYN GarageSpaces     HighSchoolDistrict PostalCode  \
# 0                 False          2.0                    NaN      92081
# 1                 False          2.0                    NaN      92264
# 2                 False          2.0                  Other      93940
# 3                   NaN          2.0        Escondido Union      92026
# 4                 False          1.0                  Other      94022
# ...                 ...          ...                    ...        ...
# 56221               NaN          2.0                    NaN      95437
# 56222             False          2.0    Los Angeles Unified      90031
# 56223             False          2.0      San Diego Unified      92114
# 56224             False          0.0  Antelope Valley Union      93544
# 56225             False          2.0   Chino Valley Unified      91709
#
#       AssociationFee LotSizeSquareFeet   logPrice
# 0              173.0            5318.0  13.854731
# 1                NaN           12632.0  14.690979
# 2                NaN            3600.0  14.461828
# 3                0.0           17248.0  13.864301
# 4                NaN           10200.0  15.590463
# ...              ...               ...        ...
# 56221            NaN           79714.8  13.422468
# 56222            0.0            7219.0  13.598598
# 56223            0.0            6900.0  13.458836
# 56224            0.0          218781.0  12.278393
# 56225          141.0            4937.0  13.976779
#
# [56226 rows x 45 columns]

# %%
test = pd.read_csv("test_trim.csv")
test
# Out:
#             BuyerAgentAOR           Flooring ViewYN PoolPrivateYN   CloseDate  \
# 0             ContraCosta   Carpet,Tile,Wood    NaN         False  2025-12-31
# 1                SanDiego        Carpet,Wood   True         False  2025-12-31
# 2             Mlslistings                NaN  False           NaN  2025-12-31
# 3             Mlslistings                NaN  False           NaN  2025-12-31
# 4             Mlslistings                NaN  False           NaN  2025-12-31
# ...                   ...                ...    ...           ...         ...
# 10345         Mlslistings  Carpet,Stone,Wood   True           NaN  2025-12-01
# 10346            Glendale          Tile,Wood   True         False  2025-12-05
# 10347  NorthSanLuisObispo    Carpet,Laminate   True         False  2025-12-17
# 10348    TheInlandGateway                NaN   True         False  2025-12-15
# 10349    TheInlandGateway           Laminate   True         False  2025-12-01
#
#        ClosePrice   Latitude   Longitude           UnparsedAddress  \
# 0       1998000.0  37.871927 -122.029871          645 Appaloosa Dr
# 1       2214421.0  34.150680 -118.580650        4421 Natoma Avenue
# 2       1200000.0  37.306405 -121.835428         2703 Apollo Drive
# 3       3100000.0  37.272636 -121.921351          2703 Sutro Drive
# 4       2900000.0  37.303942 -121.935424            940 Arnold Way
# ...           ...        ...         ...                       ...
# 10345    479500.0  36.351756 -121.582590      39450 Tassajara Road
# 10346    640000.0  34.608952 -118.259648  7211 Elizabeth Lake Road
# 10347    600000.0  35.903719 -120.982965     70255 New Pleyto Road
# 10348    380000.0  34.261375 -117.211842     27121 Peninsula Drive
# 10349    842000.0  33.746161 -118.022037          14862 Sabre Lane
#
#       PropertyType  ...  Levels  LotSizeArea MainLevelBedrooms  \
# 0      Residential  ...     One      10080.0               NaN
# 1      Residential  ...     Two      34745.0               NaN
# 2      Residential  ...     NaN       6600.0               NaN
# 3      Residential  ...     NaN       8262.0               NaN
# 4      Residential  ...     NaN       9222.0               NaN
# ...            ...  ...     ...          ...               ...
# 10345  Residential  ...     NaN    1745449.0               NaN
# 10346  Residential  ...     One     105281.0               3.0
# 10347  Residential  ...     One         20.0               3.0
# 10348  Residential  ...     One       9620.0               3.0
# 10349  Residential  ...     One       7275.0               3.0
#
#       NewConstructionYN GarageSpaces           HighSchoolDistrict PostalCode  \
# 0                 False          3.0             San Ramon Valley      94596
# 1                 False          3.0                          NaN      91364
# 2                 False          2.0                        Other      95121
# 3                 False          1.0             San Jose Unified      95124
# 4                 False          2.0                        Other      95128
# ...                 ...          ...                          ...        ...
# 10345             False          0.0               Carmel Unified      93924
# 10346             False          3.0        Antelope Valley Union      93551
# 10347             False          0.0        King City Joint Union      93426
# 10348             False          1.0             Rim of the World      92352
# 10349             False          2.0  Huntington Beach Union High      92647
#
#       AssociationFee LotSizeSquareFeet   logPrice
# 0              975.0           10080.0  14.507657
# 1                NaN           34745.0  14.610502
# 2                NaN            6600.0  13.997832
# 3                NaN            8262.0  14.946913
# 4                NaN            9222.0  14.880221
# ...              ...               ...        ...
# 10345            NaN         1745449.0  13.080499
# 10346            0.0          105281.0  13.369223
# 10347            0.0          871200.0  13.304685
# 10348            0.0            9620.0  12.847927
# 10349            0.0            7275.0  13.643535
#
# [10350 rows x 45 columns]

# %%
train.columns
# Out:
# Index(['BuyerAgentAOR', 'Flooring', 'ViewYN', 'PoolPrivateYN', 'CloseDate',
#        'ClosePrice', 'Latitude', 'Longitude', 'UnparsedAddress',
#        'PropertyType', 'LivingArea', 'DaysOnMarket', 'ListOfficeName',
#        'BuyerOfficeName', 'BuyerAgentMlsId', 'BuyerAgentFirstName',
#        'BuyerAgentLastName', 'MLSAreaMajor', 'CountyOrParish', 'MlsStatus',
#        'AttachedGarageYN', 'ParkingTotal', 'PropertySubType', 'LotSizeAcres',
#        'BuyerOfficeAOR', 'YearBuilt', 'StreetNumberNumeric',
#        'BathroomsTotalInteger', 'City', 'BedroomsTotal',
#        'ContractStatusChangeDate', 'PurchaseContractDate', 'StateOrProvince',
#        'FireplaceYN', 'Stories', 'Levels', 'LotSizeArea', 'MainLevelBedrooms',
#        'NewConstructionYN', 'GarageSpaces', 'HighSchoolDistrict', 'PostalCode',
#        'AssociationFee', 'LotSizeSquareFeet', 'logPrice'],
#       dtype='object')

# %% [markdown]
# Linear Regression

# %%
y_train = train['logPrice']
y_test  = test['logPrice']

X_train = train[cols]
X_test  = test[cols]

# %%
from sklearn.linear_model import LinearRegression

lm = LinearRegression()
lm.fit(X_train, y_train)

y_pred_log = lm.predict(X_test)

# %% [markdown]
# Check $R^2$

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred_log)
r2
# Out:
# 0.38080304906062246

# %% [markdown]
# MdAPE

# %%
y_test_price = np.exp(y_test)
y_pred_price = np.exp(y_pred_log)

MdAPE = np.median(np.abs(y_test_price - y_pred_price) / y_test_price) * 100
MdAPE
# Out:
# np.float64(33.00282186512257)

# %%
residuals = y_test - y_pred_log

import scipy.stats as stats

stats.probplot(residuals, dist="norm", plot=plt)
plt.title("QQ Plot of Prediction Residuals")
plt.show()
