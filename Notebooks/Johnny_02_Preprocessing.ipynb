# %% [markdown]
# ### Considerations
#
#
# - Drop `StreetNumberNumeric`
# - KNN Imputation for high importance, nonbinary features
# - RobustScaler works best for many of our features, almost all of which are left-skewed.
# - x_robust_scaled = (X - median) / (Q3 - Q1)
# - For extreme skews could log or sqrt-transform and then use StandardScaler
# - Investigate extreme outliers in SqFeet and GarageSpaces (are they even valid properties)

# %% [markdown]
# |
